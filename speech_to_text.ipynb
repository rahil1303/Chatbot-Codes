# %%
pip install speechrecognition
# Out:
# Collecting speechrecognition
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
#      |████████████████████████████████| 32.8 MB 44.6 MB/s eta 0:00:01
# Installing collected packages: speechrecognition
# Successfully installed speechrecognition-3.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
# Collecting pyobjc>=2.4; platform_system == "Darwin"
#   Downloading pyobjc-7.0-py3-none-any.whl (3.0 kB)
# Collecting pyobjc-framework-DiscRecording==7.0
#   Downloading pyobjc_framework_DiscRecording-7.0-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-LocalAuthentication==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_LocalAuthentication-7.0-py2.py3-none-any.whl (4.8 kB)
# Collecting pyobjc-framework-ContactsUI==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_ContactsUI-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.0 kB)
# Collecting pyobjc-framework-ExceptionHandling==7.0
#   Downloading pyobjc_framework_ExceptionHandling-7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting pyobjc-framework-Intents==7.0; platform_release >= "16.0"
#   Downloading pyobjc_framework_Intents-7.0-cp36-abi3-macosx_10_9_x86_64.whl (19 kB)
# Collecting pyobjc-framework-SystemExtensions==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_SystemExtensions-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.4 kB)
# Collecting pyobjc-framework-CoreMedia==7.0; platform_release >= "11.0"
#   Downloading pyobjc_framework_CoreMedia-7.0-cp38-cp38-macosx_10_9_x86_64.whl (18 kB)
# Collecting pyobjc-framework-DVDPlayback==7.0
#   Downloading pyobjc_framework_DVDPlayback-7.0-py2.py3-none-any.whl (7.6 kB)
# Collecting pyobjc-framework-UserNotifications==7.0; platform_release >= "18.0"
#   Downloading pyobjc_framework_UserNotifications-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.1 kB)
# Collecting pyobjc-framework-NetworkExtension==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_NetworkExtension-7.0-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-CalendarStore==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_CalendarStore-7.0-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-PreferencePanes==7.0
#   Downloading pyobjc_framework_PreferencePanes-7.0-py2.py3-none-any.whl (4.2 kB)
# Collecting pyobjc-framework-ImageCaptureCore==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_ImageCaptureCore-7.0-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-VideoToolbox==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_VideoToolbox-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.3 kB)
# Collecting pyobjc-framework-FileProvider==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_FileProvider-7.0-cp38-cp38-macosx_10_9_x86_64.whl (8.3 kB)
# Collecting pyobjc-framework-SecurityFoundation==7.0
#   Downloading pyobjc_framework_SecurityFoundation-7.0-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-CoreMotion==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_CoreMotion-7.0-py2.py3-none-any.whl (4.1 kB)
# Collecting pyobjc-framework-EventKit==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_EventKit-7.0-py2.py3-none-any.whl (5.6 kB)
# Collecting pyobjc-framework-MapKit==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_MapKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-ApplicationServices==7.0
#   Downloading pyobjc_framework_ApplicationServices-7.0-py2.py3-none-any.whl (19 kB)
# Collecting pyobjc-framework-DeviceCheck==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_DeviceCheck-7.0-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-MediaToolbox==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_MediaToolbox-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.4 kB)
# Collecting pyobjc-framework-CoreAudio==7.0
#   Downloading pyobjc_framework_CoreAudio-7.0-cp38-cp38-macosx_10_9_x86_64.whl (24 kB)
# Collecting pyobjc-framework-CoreMIDI==7.0
#   Downloading pyobjc_framework_CoreMIDI-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.0 kB)
# Collecting pyobjc-framework-AddressBook==7.0
#   Downloading pyobjc_framework_AddressBook-7.0-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-AppleScriptObjC==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_AppleScriptObjC-7.0-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-AVFoundation==7.0; platform_release >= "11.0"
#   Downloading pyobjc_framework_AVFoundation-7.0-cp36-abi3-macosx_10_9_x86_64.whl (37 kB)
# Collecting pyobjc-framework-BusinessChat==7.0; platform_release >= "18.0"
#   Downloading pyobjc_framework_BusinessChat-7.0-py2.py3-none-any.whl (2.9 kB)
# Collecting pyobjc-framework-ExecutionPolicy==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_ExecutionPolicy-7.0-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-Social==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_Social-7.0-py2.py3-none-any.whl (3.9 kB)
# Collecting pyobjc-framework-CoreLocation==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_CoreLocation-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.0 kB)
# Collecting pyobjc-framework-AVKit==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_AVKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.4 kB)
# Collecting pyobjc-framework-LinkPresentation==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_LinkPresentation-7.0-py2.py3-none-any.whl (3.2 kB)
# Collecting pyobjc-framework-CoreSpotlight==7.0; platform_release >= "17.0"
#   Downloading pyobjc_framework_CoreSpotlight-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.1 kB)
# Collecting pyobjc-framework-WebKit==7.0
#   Downloading pyobjc_framework_WebKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (26 kB)
# Collecting pyobjc-framework-CoreHaptics==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_CoreHaptics-7.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-Collaboration==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_Collaboration-7.0-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-AuthenticationServices==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_AuthenticationServices-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.6 kB)
# Collecting pyobjc-framework-QuickLookThumbnailing==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_QuickLookThumbnailing-7.0-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-Automator==7.0
#   Downloading pyobjc_framework_Automator-7.0-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-DiskArbitration==7.0
#   Downloading pyobjc_framework_DiskArbitration-7.0-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-CoreMediaIO==7.0; platform_release >= "11.0"
#   Downloading pyobjc_framework_CoreMediaIO-7.0-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-OpenDirectory==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_OpenDirectory-7.0-py2.py3-none-any.whl (11 kB)
# Collecting pyobjc-framework-SafariServices==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_SafariServices-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.0 kB)
# Collecting pyobjc-framework-Speech==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_Speech-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.6 kB)
# Collecting pyobjc-core==7.0
#   Downloading pyobjc_core-7.0-cp38-cp38-macosx_10_9_x86_64.whl (292 kB)
#      |████████████████████████████████| 292 kB 7.1 MB/s eta 0:00:01
# Collecting pyobjc-framework-CloudKit==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_CloudKit-7.0-py2.py3-none-any.whl (7.2 kB)
# Collecting pyobjc-framework-AdSupport==7.0; platform_release >= "18.0"
#   Downloading pyobjc_framework_AdSupport-7.0-py2.py3-none-any.whl (2.9 kB)
# Collecting pyobjc-framework-CoreML==7.0; platform_release >= "17.0"
#   Downloading pyobjc_framework_CoreML-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.1 kB)
# Collecting pyobjc-framework-ModelIO==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_ModelIO-7.0-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-libdispatch==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_libdispatch-7.0-cp38-cp38-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-PushKit==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_PushKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.1 kB)
# Collecting pyobjc-framework-CoreText==7.0
#   Downloading pyobjc_framework_CoreText-7.0-cp38-cp38-macosx_10_9_x86_64.whl (23 kB)
# Collecting pyobjc-framework-VideoSubscriberAccount==7.0; platform_release >= "18.0"
#   Downloading pyobjc_framework_VideoSubscriberAccount-7.0-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-Photos==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_Photos-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.1 kB)
# Collecting pyobjc-framework-LaunchServices==7.0
#   Downloading pyobjc_framework_LaunchServices-7.0-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-CoreServices==7.0
#   Downloading pyobjc_framework_CoreServices-7.0-cp36-abi3-macosx_10_9_x86_64.whl (27 kB)
# Collecting pyobjc-framework-MediaLibrary==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_MediaLibrary-7.0-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-GameplayKit==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_GameplayKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.6 kB)
# Collecting pyobjc-framework-PhotosUI==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_PhotosUI-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.9 kB)
# Collecting pyobjc-framework-AutomaticAssessmentConfiguration==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_AutomaticAssessmentConfiguration-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.2 kB)
# Collecting pyobjc-framework-SystemConfiguration==7.0
#   Downloading pyobjc_framework_SystemConfiguration-7.0-cp36-abi3-macosx_10_9_x86_64.whl (17 kB)
# Collecting pyobjc-framework-FileProviderUI==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_FileProviderUI-7.0-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-Metal==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_Metal-7.0-cp36-abi3-macosx_10_9_x86_64.whl (26 kB)
# Collecting pyobjc-framework-IOSurface==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_IOSurface-7.0-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-CryptoTokenKit==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_CryptoTokenKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.4 kB)
# Collecting pyobjc-framework-AppleScriptKit==7.0
#   Downloading pyobjc_framework_AppleScriptKit-7.0-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-MediaPlayer==7.0; platform_release >= "16.0"
#   Downloading pyobjc_framework_MediaPlayer-7.0-py2.py3-none-any.whl (5.7 kB)
# Collecting pyobjc-framework-CoreBluetooth==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_CoreBluetooth-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.8 kB)
# Collecting pyobjc-framework-CoreData==7.0
#   Downloading pyobjc_framework_CoreData-7.0-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-MediaAccessibility==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_MediaAccessibility-7.0-py2.py3-none-any.whl (3.8 kB)
# Collecting pyobjc-framework-NotificationCenter==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_NotificationCenter-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.4 kB)
# Collecting pyobjc-framework-FinderSync==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_FinderSync-7.0-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-StoreKit==7.0; platform_release >= "11.0"
#   Downloading pyobjc_framework_StoreKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.5 kB)
# Collecting pyobjc-framework-SceneKit==7.0; platform_release >= "11.0"
#   Downloading pyobjc_framework_SceneKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (21 kB)
# Collecting pyobjc-framework-SpriteKit==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_SpriteKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (11 kB)
# Collecting pyobjc-framework-MetalPerformanceShaders==7.0; platform_release >= "17.0"
#   Downloading pyobjc_framework_MetalPerformanceShaders-7.0-cp36-abi3-macosx_10_9_x86_64.whl (16 kB)
# Collecting pyobjc-framework-Accounts==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_Accounts-7.0-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-SoundAnalysis==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_SoundAnalysis-7.0-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-Security==7.0
#   Downloading pyobjc_framework_Security-7.0-cp38-cp38-macosx_10_9_x86_64.whl (30 kB)
# Collecting pyobjc-framework-MultipeerConnectivity==7.0; platform_release >= "14.0"
#   Downloading pyobjc_framework_MultipeerConnectivity-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.0 kB)
# Collecting pyobjc-framework-InputMethodKit==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_InputMethodKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.6 kB)
# Collecting pyobjc-framework-ExternalAccessory==7.0; platform_release >= "17.0"
#   Downloading pyobjc_framework_ExternalAccessory-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.7 kB)
# Collecting pyobjc-framework-Contacts==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_Contacts-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.2 kB)
# Collecting pyobjc-framework-InstallerPlugins==7.0
#   Downloading pyobjc_framework_InstallerPlugins-7.0-py2.py3-none-any.whl (4.3 kB)
# Collecting pyobjc-framework-NetFS==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_NetFS-7.0-py2.py3-none-any.whl (3.7 kB)
# Collecting pyobjc-framework-SecurityInterface==7.0
#   Downloading pyobjc_framework_SecurityInterface-7.0-cp36-abi3-macosx_10_9_x86_64.whl (7.8 kB)
# Collecting pyobjc-framework-IMServicePlugIn==7.0; platform_release >= "11.0"
#   Downloading pyobjc_framework_IMServicePlugIn-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.7 kB)
# Collecting pyobjc-framework-NaturalLanguage==7.0; platform_release >= "18.0"
#   Downloading pyobjc_framework_NaturalLanguage-7.0-py2.py3-none-any.whl (4.2 kB)
# Collecting pyobjc-framework-GameController==7.0; platform_release >= "13.0"
#   Downloading pyobjc_framework_GameController-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.2 kB)
# Collecting pyobjc-framework-SearchKit==7.0
#   Downloading pyobjc_framework_SearchKit-7.0-py2.py3-none-any.whl (3.3 kB)
# Collecting pyobjc-framework-MetalKit==7.0; platform_release >= "15.0"
#   Downloading pyobjc_framework_MetalKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.6 kB)
# Collecting pyobjc-framework-DiscRecordingUI==7.0
#   Downloading pyobjc_framework_DiscRecordingUI-7.0-py2.py3-none-any.whl (4.2 kB)
# Collecting pyobjc-framework-Network==7.0; platform_release >= "18.0"
#   Downloading pyobjc_framework_Network-7.0-cp36-abi3-macosx_10_9_x86_64.whl (13 kB)
# Collecting pyobjc-framework-iTunesLibrary==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_iTunesLibrary-7.0-py2.py3-none-any.whl (4.5 kB)
# Collecting pyobjc-framework-Quartz==7.0
#   Downloading pyobjc_framework_Quartz-7.0-cp38-cp38-macosx_10_9_x86_64.whl (141 kB)
#      |████████████████████████████████| 141 kB 7.4 MB/s eta 0:00:01
# Collecting pyobjc-framework-ScriptingBridge==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_ScriptingBridge-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.8 kB)
# Collecting pyobjc-framework-PencilKit==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_PencilKit-7.0-py2.py3-none-any.whl (3.1 kB)
# Collecting pyobjc-framework-CFNetwork==7.0
#   Downloading pyobjc_framework_CFNetwork-7.0-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-ScreenSaver==7.0
#   Downloading pyobjc_framework_ScreenSaver-7.0-cp36-abi3-macosx_10_9_x86_64.whl (6.2 kB)
# Collecting pyobjc-framework-GameCenter==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_GameCenter-7.0-cp36-abi3-macosx_10_9_x86_64.whl (12 kB)
# Collecting pyobjc-framework-Vision==7.0; platform_release >= "17.0"
#   Downloading pyobjc_framework_Vision-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.3 kB)
# Collecting pyobjc-framework-CoreWLAN==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_CoreWLAN-7.0-cp36-abi3-macosx_10_9_x86_64.whl (8.3 kB)
# Collecting pyobjc-framework-SyncServices==7.0
#   Downloading pyobjc_framework_SyncServices-7.0-cp36-abi3-macosx_10_9_x86_64.whl (10 kB)
# Collecting pyobjc-framework-ColorSync==7.0; platform_release >= "17.0"
#   Downloading pyobjc_framework_ColorSync-7.0-py2.py3-none-any.whl (5.1 kB)
# Collecting pyobjc-framework-CoreAudioKit==7.0
#   Downloading pyobjc_framework_CoreAudioKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (5.7 kB)
# Collecting pyobjc-framework-FSEvents==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_FSEvents-7.0-cp36-abi3-macosx_10_9_x86_64.whl (9.1 kB)
# Collecting pyobjc-framework-DictionaryServices==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_DictionaryServices-7.0-py2.py3-none-any.whl (3.4 kB)
# Collecting pyobjc-framework-LatentSemanticMapping==7.0
#   Downloading pyobjc_framework_LatentSemanticMapping-7.0-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-OSLog==7.0; platform_release >= "19.0"
#   Downloading pyobjc_framework_OSLog-7.0-cp36-abi3-macosx_10_9_x86_64.whl (5.9 kB)
# Collecting pyobjc-framework-OSAKit==7.0
#   Downloading pyobjc_framework_OSAKit-7.0-py2.py3-none-any.whl (3.5 kB)
# Collecting pyobjc-framework-ServiceManagement==7.0; platform_release >= "10.0"
#   Downloading pyobjc_framework_ServiceManagement-7.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pyobjc-framework-GameKit==7.0; platform_release >= "12.0"
#   Downloading pyobjc_framework_GameKit-7.0-cp36-abi3-macosx_10_9_x86_64.whl (14 kB)
# Collecting pyobjc-framework-InstantMessage==7.0; platform_release >= "9.0"
#   Downloading pyobjc_framework_InstantMessage-7.0-py2.py3-none-any.whl (4.9 kB)
# Collecting pyobjc-framework-Cocoa==7.0
#   Downloading pyobjc_framework_Cocoa-7.0-cp38-cp38-macosx_10_9_x86_64.whl (261 kB)
#      |████████████████████████████████| 261 kB 11.1 MB/s eta 0:00:01
# Installing collected packages: pyobjc-core, pyobjc-framework-Cocoa, pyobjc-framework-DiscRecording, pyobjc-framework-LocalAuthentication, pyobjc-framework-Contacts, pyobjc-framework-ContactsUI, pyobjc-framework-ExceptionHandling, pyobjc-framework-Intents, pyobjc-framework-SystemExtensions, pyobjc-framework-CoreMedia, pyobjc-framework-DVDPlayback, pyobjc-framework-UserNotifications, pyobjc-framework-NetworkExtension, pyobjc-framework-CalendarStore, pyobjc-framework-PreferencePanes, pyobjc-framework-ImageCaptureCore, pyobjc-framework-Quartz, pyobjc-framework-VideoToolbox, pyobjc-framework-FileProvider, pyobjc-framework-Security, pyobjc-framework-SecurityFoundation, pyobjc-framework-CoreMotion, pyobjc-framework-EventKit, pyobjc-framework-CoreLocation, pyobjc-framework-MapKit, pyobjc-framework-ApplicationServices, pyobjc-framework-DeviceCheck, pyobjc-framework-MediaToolbox, pyobjc-framework-CoreAudio, pyobjc-framework-CoreMIDI, pyobjc-framework-AddressBook, pyobjc-framework-AppleScriptObjC, pyobjc-framework-AVFoundation, pyobjc-framework-BusinessChat, pyobjc-framework-ExecutionPolicy, pyobjc-framework-Social, pyobjc-framework-AVKit, pyobjc-framework-LinkPresentation, pyobjc-framework-CoreSpotlight, pyobjc-framework-WebKit, pyobjc-framework-CoreHaptics, pyobjc-framework-Collaboration, pyobjc-framework-AuthenticationServices, pyobjc-framework-QuickLookThumbnailing, pyobjc-framework-Automator, pyobjc-framework-DiskArbitration, pyobjc-framework-CoreMediaIO, pyobjc-framework-OpenDirectory, pyobjc-framework-SafariServices, pyobjc-framework-Speech, pyobjc-framework-CoreData, pyobjc-framework-Accounts, pyobjc-framework-CloudKit, pyobjc-framework-AdSupport, pyobjc-framework-CoreML, pyobjc-framework-ModelIO, pyobjc-framework-libdispatch, pyobjc-framework-PushKit, pyobjc-framework-CoreText, pyobjc-framework-VideoSubscriberAccount, pyobjc-framework-Photos, pyobjc-framework-FSEvents, pyobjc-framework-CoreServices, pyobjc-framework-LaunchServices, pyobjc-framework-MediaLibrary, pyobjc-framework-SpriteKit, pyobjc-framework-GameplayKit, pyobjc-framework-PhotosUI, pyobjc-framework-AutomaticAssessmentConfiguration, pyobjc-framework-SystemConfiguration, pyobjc-framework-FileProviderUI, pyobjc-framework-Metal, pyobjc-framework-IOSurface, pyobjc-framework-CryptoTokenKit, pyobjc-framework-AppleScriptKit, pyobjc-framework-MediaPlayer, pyobjc-framework-CoreBluetooth, pyobjc-framework-MediaAccessibility, pyobjc-framework-NotificationCenter, pyobjc-framework-FinderSync, pyobjc-framework-StoreKit, pyobjc-framework-SceneKit, pyobjc-framework-MetalPerformanceShaders, pyobjc-framework-SoundAnalysis, pyobjc-framework-MultipeerConnectivity, pyobjc-framework-InputMethodKit, pyobjc-framework-ExternalAccessory, pyobjc-framework-InstallerPlugins, pyobjc-framework-NetFS, pyobjc-framework-SecurityInterface, pyobjc-framework-IMServicePlugIn, pyobjc-framework-NaturalLanguage, pyobjc-framework-GameController, pyobjc-framework-SearchKit, pyobjc-framework-MetalKit, pyobjc-framework-DiscRecordingUI, pyobjc-framework-Network, pyobjc-framework-iTunesLibrary, pyobjc-framework-ScriptingBridge, pyobjc-framework-PencilKit, pyobjc-framework-CFNetwork, pyobjc-framework-ScreenSaver, pyobjc-framework-GameCenter, pyobjc-framework-Vision, pyobjc-framework-CoreWLAN, pyobjc-framework-SyncServices, pyobjc-framework-ColorSync, pyobjc-framework-CoreAudioKit, pyobjc-framework-DictionaryServices, pyobjc-framework-LatentSemanticMapping, pyobjc-framework-OSLog, pyobjc-framework-OSAKit, pyobjc-framework-ServiceManagement, pyobjc-framework-GameKit, pyobjc-framework-InstantMessage, pyobjc, pyttsx3
# Successfully installed pyobjc-7.0 pyobjc-core-7.0 pyobjc-framework-AVFoundation-7.0 pyobjc-framework-AVKit-7.0 pyobjc-framework-Accounts-7.0 pyobjc-framework-AdSupport-7.0 pyobjc-framework-AddressBook-7.0 pyobjc-framework-AppleScriptKit-7.0 pyobjc-framework-AppleScriptObjC-7.0 pyobjc-framework-ApplicationServices-7.0 pyobjc-framework-AuthenticationServices-7.0 pyobjc-framework-AutomaticAssessmentConfiguration-7.0 pyobjc-framework-Automator-7.0 pyobjc-framework-BusinessChat-7.0 pyobjc-framework-CFNetwork-7.0 pyobjc-framework-CalendarStore-7.0 pyobjc-framework-CloudKit-7.0 pyobjc-framework-Cocoa-7.0 pyobjc-framework-Collaboration-7.0 pyobjc-framework-ColorSync-7.0 pyobjc-framework-Contacts-7.0 pyobjc-framework-ContactsUI-7.0 pyobjc-framework-CoreAudio-7.0 pyobjc-framework-CoreAudioKit-7.0 pyobjc-framework-CoreBluetooth-7.0 pyobjc-framework-CoreData-7.0 pyobjc-framework-CoreHaptics-7.0 pyobjc-framework-CoreLocation-7.0 pyobjc-framework-CoreMIDI-7.0 pyobjc-framework-CoreML-7.0 pyobjc-framework-CoreMedia-7.0 pyobjc-framework-CoreMediaIO-7.0 pyobjc-framework-CoreMotion-7.0 pyobjc-framework-CoreServices-7.0 pyobjc-framework-CoreSpotlight-7.0 pyobjc-framework-CoreText-7.0 pyobjc-framework-CoreWLAN-7.0 pyobjc-framework-CryptoTokenKit-7.0 pyobjc-framework-DVDPlayback-7.0 pyobjc-framework-DeviceCheck-7.0 pyobjc-framework-DictionaryServices-7.0 pyobjc-framework-DiscRecording-7.0 pyobjc-framework-DiscRecordingUI-7.0 pyobjc-framework-DiskArbitration-7.0 pyobjc-framework-EventKit-7.0 pyobjc-framework-ExceptionHandling-7.0 pyobjc-framework-ExecutionPolicy-7.0 pyobjc-framework-ExternalAccessory-7.0 pyobjc-framework-FSEvents-7.0 pyobjc-framework-FileProvider-7.0 pyobjc-framework-FileProviderUI-7.0 pyobjc-framework-FinderSync-7.0 pyobjc-framework-GameCenter-7.0 pyobjc-framework-GameController-7.0 pyobjc-framework-GameKit-7.0 pyobjc-framework-GameplayKit-7.0 pyobjc-framework-IMServicePlugIn-7.0 pyobjc-framework-IOSurface-7.0 pyobjc-framework-ImageCaptureCore-7.0 pyobjc-framework-InputMethodKit-7.0 pyobjc-framework-InstallerPlugins-7.0 pyobjc-framework-InstantMessage-7.0 pyobjc-framework-Intents-7.0 pyobjc-framework-LatentSemanticMapping-7.0 pyobjc-framework-LaunchServices-7.0 pyobjc-framework-LinkPresentation-7.0 pyobjc-framework-LocalAuthentication-7.0 pyobjc-framework-MapKit-7.0 pyobjc-framework-MediaAccessibility-7.0 pyobjc-framework-MediaLibrary-7.0 pyobjc-framework-MediaPlayer-7.0 pyobjc-framework-MediaToolbox-7.0 pyobjc-framework-Metal-7.0 pyobjc-framework-MetalKit-7.0 pyobjc-framework-MetalPerformanceShaders-7.0 pyobjc-framework-ModelIO-7.0 pyobjc-framework-MultipeerConnectivity-7.0 pyobjc-framework-NaturalLanguage-7.0 pyobjc-framework-NetFS-7.0 pyobjc-framework-Network-7.0 pyobjc-framework-NetworkExtension-7.0 pyobjc-framework-NotificationCenter-7.0 pyobjc-framework-OSAKit-7.0 pyobjc-framework-OSLog-7.0 pyobjc-framework-OpenDirectory-7.0 pyobjc-framework-PencilKit-7.0 pyobjc-framework-Photos-7.0 pyobjc-framework-PhotosUI-7.0 pyobjc-framework-PreferencePanes-7.0 pyobjc-framework-PushKit-7.0 pyobjc-framework-Quartz-7.0 pyobjc-framework-QuickLookThumbnailing-7.0 pyobjc-framework-SafariServices-7.0 pyobjc-framework-SceneKit-7.0 pyobjc-framework-ScreenSaver-7.0 pyobjc-framework-ScriptingBridge-7.0 pyobjc-framework-SearchKit-7.0 pyobjc-framework-Security-7.0 pyobjc-framework-SecurityFoundation-7.0 pyobjc-framework-SecurityInterface-7.0 pyobjc-framework-ServiceManagement-7.0 pyobjc-framework-Social-7.0 pyobjc-framework-SoundAnalysis-7.0 pyobjc-framework-Speech-7.0 pyobjc-framework-SpriteKit-7.0 pyobjc-framework-StoreKit-7.0 pyobjc-framework-SyncServices-7.0 pyobjc-framework-SystemConfiguration-7.0 pyobjc-framework-SystemExtensions-7.0 pyobjc-framework-UserNotifications-7.0 pyobjc-framework-VideoSubscriberAccount-7.0 pyobjc-framework-VideoToolbox-7.0 pyobjc-framework-Vision-7.0 pyobjc-framework-WebKit-7.0 pyobjc-framework-iTunesLibrary-7.0 pyobjc-framework-libdispatch-7.0 pyttsx3-2.90
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Requirement already satisfied: pyaudio in ./opt/anaconda3/lib/python3.8/site-packages (0.2.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr 
import pyttsx3

# %%
# Initialize the recognizer  
r = sr.Recognizer()

# %%
# Function to convert text to 
# speech 
def SpeakText(command): 
      
    # Initialize the engine 
    engine = pyttsx3.init() 
    engine.say(command)  
    engine.runAndWait() 
      
      
# Loop infinitely for user to 
# speak 
  
while(1):     
      
    # Exception handling to handle 
    # exceptions at the runtime 
    try: 
          
        # use the microphone as source for input. 
        with sr.Microphone() as source2: 
              
            # wait for a second to let the recognizer 
            # adjust the energy threshold based on 
            # the surrounding noise level  
            r.adjust_for_ambient_noise(source2, duration=0.2) 
              
            #listens for the user's input  
            audio2 = r.listen(source2) 
              
            # Using ggogle to recognize audio 
            MyText = r.recognize_google(audio2) 
            MyText = MyText.lower() 
  
            print("Did you say "+MyText) 
            SpeakText(MyText) 
              
    except sr.RequestError as e: 
        print("Could not request results; {0}".format(e)) 
          
    except sr.UnknownValueError: 
        print("unknown error occured")
# Out:
# Did you say hello my name is sahil
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pyttsx3/__init__.py in init(driverName, debug)
#      19     try:
# ---> 20         eng = _activeEngines[driverName]
#      21     except KeyError:
#
# ~/opt/anaconda3/lib/python3.8/weakref.py in __getitem__(self, key)
#     130             self._commit_removals()
# --> 131         o = self.data[key]()
#     132         if o is None:
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-13-0d3dc5020d02> in <module>
#      34
#      35             print("Did you say "+MyText)
# ---> 36             SpeakText(MyText)
#      37
#      38     except sr.RequestError as e:
#
# <ipython-input-13-0d3dc5020d02> in SpeakText(command)
#       4
#       5     # Initialize the engine
# ----> 6     engine = pyttsx3.init()
#       7     engine.say(command)
#       8     engine.runAndWait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyttsx3/__init__.py in init(driverName, debug)
#      20         eng = _activeEngines[driverName]
#      21     except KeyError:
# ---> 22         eng = Engine(driverName, debug)
#      23         _activeEngines[driverName] = eng
#      24     return eng
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyttsx3/engine.py in __init__(self, driverName, debug)
#      28         @type debug: bool
#      29         """
# ---> 30         self.proxy = driver.DriverProxy(weakref.proxy(self), driverName, debug)
#      31         # initialize other vars
#      32         self._connects = {}
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyttsx3/driver.py in __init__(self, engine, driverName, debug)
#      48         # import driver module
#      49         name = 'pyttsx3.drivers.%s' % driverName
# ---> 50         self._module = importlib.import_module(name)
#      51         # build driver instance
#      52         self._driver = self._module.buildDriver(weakref.proxy(self))
#
# ~/opt/anaconda3/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/opt/anaconda3/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pyttsx3/drivers/nsss.py in <module>
#       1
# ----> 2 from Foundation import *
#       3 from AppKit import NSSpeechSynthesizer
#       4 from PyObjCTools import AppHelper
#       5 from ..voice import Voice
#
# ~/opt/anaconda3/lib/python3.8/site-packages/Foundation/__init__.py in <module>
#       7 import sys
#       8
# ----> 9 import CoreFoundation
#      10 import Foundation._Foundation
#      11 import objc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/CoreFoundation/__init__.py in <module>
#      14     "CoreFoundation",
#      15     "com.apple.CoreFoundation",
# ---> 16     objc.pathForFramework("/System/Library/Frameworks/CoreFoundation.framework"),
#      17     _metadata.__dict__,
#      18     _inline_list_,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/objc/_dyld.py in pathForFramework(path)
#     146
#     147 def pathForFramework(path):
# --> 148     fpath, name, version = infoForFramework(dyld_find(path))
#     149     return os.path.join(fpath, name + ".framework")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/objc/_dyld.py in dyld_find(filename)
#     140     if res:
#     141         framework_loc, framework_name, version = res
# --> 142         return dyld_framework(filename, framework_name, version)
#     143     else:
#     144         return dyld_library(filename, os.path.basename(filename))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/objc/_dyld.py in dyld_framework(filename, framework_name, version)
#      99     for f in inject_suffixes(_search()):
#     100         if _dyld_shared_cache_contains_path is not None:
# --> 101             if _dyld_shared_cache_contains_path(f):
#     102                 return f
#     103
#
# NotImplementedError: _dyld_shared_cache_contains_path not available
